# %% [markdown]
# <a href="https://colab.research.google.com/github/simasaadi/noaa-nyc-climate-2020-2025/blob/main/notebooks/01_eda_noaa_nyc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Setup and data loading

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/simasaadi/noaa-nyc-climate-2020-2025/main/data/raw/noaa_nyc_annual_2020_2025.csv"

df = pd.read_csv(url)
df.head()
# Out:
#        STATION                         NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1NJHD0018        KEARNY 1.7 NNW, NJ US  40.774342 -74.137109       25.6
# 1  US1NJHD0018        KEARNY 1.7 NNW, NJ US  40.774342 -74.137109       25.6
# 2  US1NJES0018  MAPLEWOOD TWP 0.9 SE, NJ US  40.724466 -74.259542       72.5
# 3  US1NJES0018  MAPLEWOOD TWP 0.9 SE, NJ US  40.724466 -74.259542       72.5
# 4  USW00094728  NY CITY CENTRAL PARK, NY US  40.778980 -73.969250       42.7
#
#    DATE  AWND    CDSD    CLDD  DSND  ...   PRCP  SNOW  TAVG  TMAX  TMIN  TSUN  \
# 0  2023   NaN     NaN     NaN   NaN  ...  52.16   NaN   NaN   NaN   NaN   NaN
# 1  2024   NaN     NaN     NaN   NaN  ...  46.54   NaN   NaN   NaN   NaN   NaN
# 2  2020   NaN     NaN     NaN   NaN  ...  43.05   NaN   NaN   NaN   NaN   NaN
# 3  2024   NaN     NaN     NaN   NaN  ...  51.04   NaN   NaN   NaN   NaN   NaN
# 4  2020   NaN  1306.0  1306.0   9.0  ...  45.39  12.8  57.3  64.3  50.3   NaN
#
#    WDF2  WDF5  WSF2  WSF5
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 2. Basic structure and data quality checks

# %%
# Shape: how many rows and columns
df.shape
# Out:
# (219, 31)

# %%
# Columns and data types
df.dtypes
# Out:
# STATION       object
# NAME          object
# LATITUDE     float64
# LONGITUDE    float64
# ELEVATION    float64
# DATE           int64
# AWND         float64
# CDSD         float64
# CLDD         float64
# DSND         float64
# DSNW         float64
# DX32         float64
# DX70         float64
# DX90         float64
# EMNT         float64
# EMSD         float64
# EMSN         float64
# EMXP         float64
# EMXT         float64
# HDSD         float64
# HTDD         float64
# PRCP         float64
# SNOW         float64
# TAVG         float64
# TMAX         float64
# TMIN         float64
# TSUN         float64
# WDF2         float64
# WDF5         float64
# WSF2         float64
# WSF5         float64
# dtype: object

# %%
# Quick summary of numeric columns
df.describe().T
# Out:
#            count         mean         std          min          25%  \
# LATITUDE   219.0    40.753184    0.189493    40.296952    40.669501
# LONGITUDE  219.0   -74.016590    0.327623   -74.429720   -74.282840
# ELEVATION  219.0    43.226484   43.327582     0.800000     7.600000
# DATE       219.0  2022.255708    1.561698  2020.000000  2021.000000
# AWND        36.0     8.063889    2.235449     4.300000     6.850000
# CDSD        67.0  1178.432836  228.139127   782.000000   978.500000
# CLDD        67.0  1178.432836  228.139127   782.000000   978.500000
# DSND        61.0    13.573770    9.604615     0.000000     6.000000
# DSNW        82.0     4.243902    2.555850     0.000000     2.000000
# DX32        67.0     9.417910    6.410572     1.000000     3.000000
# DX70        67.0   155.238806   11.057823   130.000000   146.500000
# DX90        67.0    22.298507   11.397787     3.000000    13.000000
# EMNT        67.0     8.611940    4.327345     0.000000     5.000000
# EMSD        61.0     7.229508    4.866188     0.000000     4.000000
# EMSN        82.0     6.253659    3.643740     0.000000     4.000000
# EMXP       185.0     3.726216    1.641407     1.380000     2.680000
# EMXT        67.0    96.686567    2.786379    91.000000    94.500000
# HDSD        80.0  4590.825000  369.897891  3819.000000  4312.000000
# HTDD        80.0  4590.825000  369.897891  3819.000000  4312.000000
# PRCP       198.0    50.709242    6.352835    34.310000    46.517500
# SNOW        82.0    16.221951   10.083528     0.000000     9.025000
# TAVG        67.0    55.713433    1.602261    52.400000    54.500000
# TMAX        67.0    64.117910    1.437477    61.400000    63.000000
# TMIN        67.0    47.301493    2.190578    42.600000    45.600000
# TSUN         0.0          NaN         NaN          NaN          NaN
# WDF2        35.0   247.428571   77.737978    60.000000   165.000000
# WDF5        35.0   225.428571   80.452502    40.000000   160.000000
# WSF2        35.0    41.980000    7.337607    29.100000    38.000000
# WSF5        35.0    58.891429    7.319972    47.000000    53.900000
#
#                    50%          75%         max
# LATITUDE     40.752391    40.876450    41.12996
# LONGITUDE   -74.137109   -73.728943   -73.37309
# ELEVATION    23.200000    71.900000   188.70000
# DATE       2022.000000  2024.000000  2025.00000
# AWND          7.950000     9.725000    11.90000
# CDSD       1206.000000  1341.500000  1632.00000
# CLDD       1206.000000  1341.500000  1632.00000
# DSND         12.000000    23.000000    39.00000
# DSNW          4.000000     6.000000    11.00000
# DX32          8.000000    14.000000    26.00000
# DX70        154.000000   164.000000   180.00000
# DX90         21.000000    31.500000    49.00000
# EMNT          9.000000    12.000000    17.00000
# EMSD          6.000000    10.000000    19.00000
# EMSN          5.650000     8.000000    17.30000
# EMXP          3.200000     4.330000     9.05000
# EMXT         97.000000    98.500000   103.00000
# HDSD       4601.500000  4822.500000  5386.00000
# HTDD       4601.500000  4822.500000  5386.00000
# PRCP         49.585000    54.945000    64.77000
# SNOW         14.950000    24.000000    43.00000
# TAVG         55.700000    56.750000    58.70000
# TMAX         64.200000    65.200000    67.20000
# TMIN         47.100000    48.800000    51.90000
# TSUN               NaN          NaN         NaN
# WDF2        290.000000   310.000000   350.00000
# WDF5        260.000000   290.000000   340.00000
# WSF2         40.900000    45.550000    63.10000
# WSF5         57.900000    63.550000    79.00000

# %%
# Missing values per column
df.isna().sum().sort_values(ascending=False)
# Out:
# TSUN         219
# WDF2         184
# WSF2         184
# WDF5         184
# WSF5         184
# AWND         183
# DSND         158
# EMSD         158
# TMIN         152
# EMNT         152
# DX70         152
# DX32         152
# CLDD         152
# CDSD         152
# DX90         152
# TAVG         152
# TMAX         152
# EMXT         152
# HDSD         139
# HTDD         139
# EMSN         137
# DSNW         137
# SNOW         137
# EMXP          34
# PRCP          21
# LATITUDE       0
# LONGITUDE      0
# ELEVATION      0
# DATE           0
# NAME           0
# STATION        0
# dtype: int64

# %%
# Unique years
df["DATE"].unique(), df["DATE"].min(), df["DATE"].max()
# Out:
# (array([2023, 2024, 2020, 2021, 2022, 2025]), 2020, 2025)

# %%
# Number of unique stations
df["STATION"].nunique()
# Out:
# 58

# %% [markdown]
# ## 3. Feature engineering

# %%
df_fe = df.copy()

# Ensure DATE is integer (year)
df_fe["DATE"] = df_fe["DATE"].astype(int)

# Annual temperature range: max - min
df_fe["annual_range"] = df_fe["EMXT"] - df_fe["EMNT"]

# Total degree days (simple combo of heating degree day columns)
df_fe["total_degree_days"] = df_fe["HDSD"] + df_fe["HTDD"]

# Wetness index: precipitation + snow
df_fe["wetness_index"] = df_fe["PRCP"].fillna(0) + df_fe["SNOW"].fillna(0)

# Heat and cold extreme days (rename for clarity)
df_fe["heat_extreme_days"] = df_fe["DX90"]
df_fe["cold_extreme_days"] = df_fe["DX32"]

# Quick check of new columns
df_fe[[
    "DATE", "STATION", "TAVG", "PRCP", "SNOW",
    "annual_range", "total_degree_days",
    "wetness_index", "heat_extreme_days", "cold_extreme_days"
]].head()
# Out:
#    DATE      STATION  TAVG   PRCP  SNOW  annual_range  total_degree_days  \
# 0  2023  US1NJHD0018   NaN  52.16   NaN           NaN                NaN
# 1  2024  US1NJHD0018   NaN  46.54   NaN           NaN                NaN
# 2  2020  US1NJES0018   NaN  43.05   NaN           NaN                NaN
# 3  2024  US1NJES0018   NaN  51.04   NaN           NaN                NaN
# 4  2020  USW00094728  57.3  45.39  12.8          82.0             8666.0
#
#    wetness_index  heat_extreme_days  cold_extreme_days
# 0          52.16                NaN                NaN
# 1          46.54                NaN                NaN
# 2          43.05                NaN                NaN
# 3          51.04                NaN                NaN
# 4          58.19               20.0                6.0

# %% [markdown]
# ## 4. Save processed dataset

# %%
# Save as Parquet (efficient for Python + Streamlit)
output_path_parquet = "/content/noaa_nyc_annual_clean.parquet"
df_fe.to_parquet(output_path_parquet, index=False)

# Optionally also save as CSV for inspection
output_path_csv = "/content/noaa_nyc_annual_clean.csv"
df_fe.to_csv(output_path_csv, index=False)

output_path_parquet, output_path_csv
# Out:
# ('/content/noaa_nyc_annual_clean.parquet',
#  '/content/noaa_nyc_annual_clean.csv')

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
# ### 5.1 Summary statistics

# %%
# Quick high-level summary
df_fe[['TAVG','TMAX','TMIN','PRCP','SNOW','DX90','DX32','annual_range']].describe().T
# Out:
#               count       mean        std    min      25%     50%     75%  \
# TAVG           67.0  55.713433   1.602261  52.40  54.5000  55.700  56.750
# TMAX           67.0  64.117910   1.437477  61.40  63.0000  64.200  65.200
# TMIN           67.0  47.301493   2.190578  42.60  45.6000  47.100  48.800
# PRCP          198.0  50.709242   6.352835  34.31  46.5175  49.585  54.945
# SNOW           82.0  16.221951  10.083528   0.00   9.0250  14.950  24.000
# DX90           67.0  22.298507  11.397787   3.00  13.0000  21.000  31.500
# DX32           67.0   9.417910   6.410572   1.00   3.0000   8.000  14.000
# annual_range   67.0  88.074627   4.550436  79.00  84.0000  88.000  92.000
#
#                 max
# TAVG          58.70
# TMAX          67.20
# TMIN          51.90
# PRCP          64.77
# SNOW          43.00
# DX90          49.00
# DX32          26.00
# annual_range  97.00

# %% [markdown]
# ### 5.2 Yearly trends (across all stations)

# %%
import plotly.express as px

yearly = df_fe.groupby("DATE").agg({
    "TAVG": "mean",
    "PRCP": "sum",
    "DX90": "mean",
    "DX32": "mean"
}).reset_index()

fig = px.line(yearly, x="DATE", y="TAVG", markers=True, title="Average Annual Temperature (Across All Stations)")
fig.show()

fig = px.line(yearly, x="DATE", y="PRCP", markers=True, title="Total Annual Precipitation (Across All Stations)")
fig.show()

fig = px.line(yearly, x="DATE", y="DX90", markers=True, title="Annual Heat Extremes (Days ≥ 90°F)")
fig.show()

fig = px.line(yearly, x="DATE", y="DX32", markers=True, title="Annual Cold Extremes (Days ≤ 32°F)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4afdcd1e-d6cc-442e-bbfb-75f118be3ff5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4afdcd1e-d6cc-442e-bbfb-75f118be3ff5")) {                    Plotly.newPlot(                        "4afdcd1e-d6cc-442e-bbfb-75f118be3ff5",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003eTAVG=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[55.90714285714286,55.55714285714286,54.83076923076923,56.114285714285714,56.15833333333333,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"sca ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ef69830-d271-4217-9317-f8d9bb322b96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ef69830-d271-4217-9317-f8d9bb322b96")) {                    Plotly.newPlot(                        "6ef69830-d271-4217-9317-f8d9bb322b96",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003ePRCP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[1860.47,2013.84,1644.82,2413.25,2108.05,0.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tic ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ffbe4bb7-9b3d-4416-b485-d9758742e6c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffbe4bb7-9b3d-4416-b485-d9758742e6c4")) {                    Plotly.newPlot(                        "ffbe4bb7-9b3d-4416-b485-d9758742e6c4",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003eDX90=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[23.857142857142858,22.642857142857142,27.076923076923077,14.928571428571429,23.5,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ad921d0-930c-4c92-8709-fbf45a771d05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ad921d0-930c-4c92-8709-fbf45a771d05")) {                    Plotly.newPlot(                        "4ad921d0-930c-4c92-8709-fbf45a771d05",                        [{"hovertemplate":"DATE=%{x}\u003cbr\u003eDX32=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[6.071428571428571,11.071428571428571,19.076923076923077,2.142857142857143,9.416666666666666,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"sc ...

# %% [markdown]
# ### 5.3 Compare stations

# %%
station_means = df_fe.groupby("NAME").agg({
    "TAVG": "mean",
    "PRCP": "mean",
    "DX90": "mean",
    "annual_range": "mean"
}).reset_index()

px.bar(station_means.sort_values("TAVG"),
       x="NAME", y="TAVG", title="Average Temperature by Station").show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %% [markdown]
# ### 5.4 Correlation heatmap

# %%
import plotly.express as px
import numpy as np

numeric_df = df_fe.select_dtypes(include=[np.number])

corr = numeric_df.corr()

fig = px.imshow(
    corr,
    text_auto=True,
    aspect="auto",
    color_continuous_scale="RdBu_r",
    title="Correlation Matrix of Climate Variables"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="730416aa-8228-4571-93af-912216f5ebee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("730416aa-8228-4571-93af-912216f5ebee")) {                    Plotly.newPlot(                        "730416aa-8228-4571-93af-912216f5ebee",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["LATITUDE","LONGITUDE","ELEVATION","DATE","AWND","CDSD","CLDD","DSND","DSNW","DX32","DX70","DX90","EMNT","EMSD","EMSN","EMXP","EMXT","HDSD","HTDD","PRCP","SNOW","TAVG","TMAX","TMIN","TSUN","WDF2","WDF5","WSF2","WSF5","annual_range","total_degree_days","wetness_index","heat_extreme_days","cold_extreme_days"],"y":["LATITUDE","LONGITUDE","ELEVATION","DATE","AWND","CDSD","CLDD","DSND","DSNW","DX32","DX70","DX90","EMNT","EMSD","EMSN","EMXP","EMXT","HDSD","HTDD","PRCP","SNOW","TAVG","TMAX","TMIN","TSUN","WDF2","WDF5","WSF2","WSF5","annual_range","total_degree_days","wetness_index","heat_extreme_days","cold_extreme_days"],"z":[[1.0,0.0672316294343477,0.605363927999385,-0.0354211757160581,-0.512132125334272,-0.2846330480851539,-0.2846330480851539,0.258299220953568,0.26512605518255533,0.15442109374349583,-0.04408550592584403,-0.1289598001498224,-0.2485666859336683,0.14185369751787175,0.10018086482387316,0.12023804253856922,-0.3643201409543113,0.28811754358152314,0.28811754358152314,0.07412777823590609,0.16783334690420645,-0.2935899407574451,-0.25504425195148367,-0.25498323321207744,null,0.1243077654090627,-0.026395396985380418,-0.21493637260687934,-0.2524899759171869,0.01329539871730266,0.28811754358152314,-0.042424130588791464,-0.1289598001498224,0.15442109374349583],[0.0672316294343477,1.0,-0.24886904663999115,0.0276797156809795,0.43731420480001854,-0.3887257158040785,-0.3887257158040785,0.08534006388644187,-0.08168501806227113,0.10071952661516606,-0.6000183976165084,-0.6439896573476002,0.10859980781018254,0.09223615847936265,0.031615156018909775,-0.09228070274327345,-0.5500247230122943,0.0648975432266723,0.0648975432266723,-0.3282031568881296,-0.013235822712743643,-0.20772236746620887,-0.6080683366671028,0.09667698125901246,null,-0.12538694183948426,-0.26930124606285283,0.1758498428854461,0.20364783114638998,-0.44007347292639376,0.0648975432266723,-0.24000963367167844,-0.6439896573476002,0.10071952661516606],[0.605363927999385,-0.24886904663999115,1.0,-0.0701099124666626,-0.4591908119758381,-0.623069071933626,-0.623069071933626,0.22961688440244588,0.3214999481825472,0.23838822030568269,-0.29236671932100106,-0.3355549742973139,-0.3677897179242753,0.03317470274995552,0.010207875176423848,0.0991146072569461,-0.4444006278867919,0.6104402393207532,0.6104402393207532,0.17774983411141435,0.15096938648760144,-0.6589578276142768,-0.4984421839748538,-0.6312408835964928,null,0.1568169627217345,0.0019425426838353033,-0.3116399828966263,-0.26808021848251595,0.07763750209625156,0.6104402393207532,0.09381828986189109,-0.3355549742973139,0.23838822030568269],[-0.0354211757160581,0.0276797156809795,-0.0701099124666626,1.0,-0.20637710129850342,-0.11145902933821118,-0.11145902933821118,-0.13838052992020475,0.1363288737149911,-0.05240529046775879,0.34616120541496775,-0.11554022896248123,-0.5614112299283639,-0.49554547755929185,-0.409784252342066,-0.06721079850063628,-0.04331024412426963,-0.1975166025257452,-0.1975166025257452,0.18643727901903934,-0.14095964484066634,0.0873646247638661,0.15570045622089732,0.029890290099835695,null,-0.08291723819598065,-0.13286620663382567,-0.5147778365305024,-0.36477296507025486,0.5073670755519345,-0.1975166025257452,-0.30280203751071805,-0.11554022896248123,-0.05240529046775879],[-0.512132125334272,0.43731420480001854,-0.4591908119758381,-0.20637710129850342,1.0,0.21266380007735394,0.21266380007735394,0. ...

# %% [markdown]
# ### 5.5 Geographic map of stations

# %%
# Use station average temperature as color
station_geo = df_fe.groupby(["NAME", "LATITUDE", "LONGITUDE"]).agg({
    "TAVG": "mean",
    "PRCP": "mean"
}).reset_index()

fig = px.scatter_mapbox(
    station_geo,
    lat="LATITUDE",
    lon="LONGITUDE",
    color="TAVG",
    size="PRCP",
    hover_name="NAME",
    zoom=8,
    height=600,
    mapbox_style="carto-positron",
    title="NOAA Stations in NYC Metro Area"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="23621339-3963-4648-a061-1013f9872fd0" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23621339-3963-4648-a061-1013f9872fd0")) {                    Plotly.newPlot(                        "23621339-3963-4648-a061-1013f9872fd0",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePRCP=%{marker.size}\u003cbr\u003eLATITUDE=%{lat}\u003cbr\u003eLONGITUDE=%{lon}\u003cbr\u003eTAVG=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ALBERTSON 0.2 SSE, NY US","AMITYVILLE 0.6 NNE, NY US","ARMONK 0.3 SE, NY US","BELLMORE 0.9 SSE, NY US","BOONTON 0.6 NW, NJ US","BOONTON 1 SE, NJ US","BROOKLYN 3.1 NW, NY US","CALDWELL ESSEX CO AIRPORT, NJ US","CANOE BROOK, NJ US","CEDAR GROVE TWP 0.4 W, NJ US","CENTERPORT, NY US","CHATHAM 0.6 NE, NJ US","CLARK TWP 0.7 SSW, NJ US","CLARK TWP 1.3 ENE, NJ US","CRANFORD TWP 1.1 NNW, NJ US","EATONTOWN 1.2 NE, NJ US","FARMINGDALE REPUBLIC AIRPORT, NY US","FLORAL PARK 0.4 W, NY US","GLEN ROCK 0.7 SSE, NJ US","HARRISON, NJ US","HAWTHORNE 1.0 SSE, NJ US","HICKSVILLE 1.3 ENE, NY US","HIGHLAND PARK 0.4 NE, NJ US","HIGHLAND PARK 0.5 E, NJ US","HOWARD BEACH 0.4 NNW, NY US","JFK INTERNATIONAL AIRPORT, NY US","KEARNY 1.7 NNW, NJ US","KEARNY 1.7 N